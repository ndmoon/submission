# %% [markdown]
# Proyek Analisis Data:Bike-sharing-dataset

# %% [markdown]
# Nama : Nadia Monika Putri
#
#
# Email : nadiamonika9293@gmail.com
#
#
# ID Dicoding : nadia_monika_putri

# %% [markdown]
# Menentukan Pertanyaan Bisnis
#
# Pertanyaan 1
#
# how many bicycle users are there during the 20 hours and are there any patterns or trends in usage during these hours?
#
# Pertanyaan 2
#
# explain if there is a particular month that shows a decline in bicycle use and how many users are there in 5 months?

# %% [markdown]
# Import semua Packages/Library yang digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Wrangling
#
# Gathering Data

# %%
hour_df = pd.read_csv("data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df = pd.read_csv("data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Assessing Data

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Jumlah duplikasi: ",hour_df.duplicated().sum())
hour_df.describe()
# Out:
# Jumlah duplikasi:  0
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Jumlah duplikasi: ",day_df.duplicated().sum())
day_df.describe()
# Out:
# Jumlah duplikasi:  0
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cleaning Data

# %%
hour_df.drop_duplicates(inplace=True)

# %%
day_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df[hour_df.hr.isna()]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df[day_df.mnth.isna()]
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.hr.value_counts()
# Out:
# hr
# 17    730
# 16    730
# 13    729
# 15    729
# 14    729
# 12    728
# 22    728
# 21    728
# 20    728
# 19    728
# 18    728
# 23    728
# 11    727
# 10    727
# 9     727
# 8     727
# 7     727
# 0     726
# 6     725
# 1     724
# 5     717
# 2     715
# 4     697
# 3     697
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.mnth.value_counts()
# Out:
# mnth
# 1     62
# 3     62
# 5     62
# 7     62
# 8     62
# 10    62
# 12    62
# 4     60
# 6     60
# 9     60
# 11    60
# 2     57
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df[hour_df.hr == hour_df.hr.max()]
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 23          24  2011-01-01       1   0     1  23        0        6
# 46          47  2011-01-02       1   0     1  23        0        0
# 68          69  2011-01-03       1   0     1  23        0        1
# 91          92  2011-01-04       1   0     1  23        0        2
# 114        115  2011-01-05       1   0     1  23        0        3
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17282    17283  2012-12-27       1   1    12  23        0        4
# 17306    17307  2012-12-28       1   1    12  23        0        5
# 17330    17331  2012-12-29       1   1    12  23        0        6
# 17354    17355  2012-12-30       1   1    12  23        0        0
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 23              0           2  0.46  0.4545  0.88     0.2985      15
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df[day_df.mnth == day_df.mnth.max()]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 334      335  2011-12-01       4   0    12        0        4           1
# 335      336  2011-12-02       4   0    12        0        5           1
# 336      337  2011-12-03       4   0    12        0        6           0
# 337      338  2011-12-04       4   0    12        0        0           0
# 338      339  2011-12-05       4   0    12        0        1           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %% [markdown]
# Explore...

# %%
hour_df.describe(include="all")
# Out:
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-01-01           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
#                   hr       holiday       weekday    workingday    weathersit  \
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-01-01         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.groupby(by="hr").agg({
    "instant": "nunique",
    "hr": ["max", "min", "mean", "std"]
})
# Out:
#    instant  hr
#    nunique max min  mean  std
# hr
# 0      726   0   0   0.0  0.0
# 1      724   1   1   1.0  0.0
# 2      715   2   2   2.0  0.0
# 3      697   3   3   3.0  0.0
# 4      697   4   4   4.0  0.0
# 5      717   5   5   5.0  0.0
# 6      725   6   6   6.0  0.0
# 7      727   7   7   7.0  0.0
# 8      727   8   8   8.0  0.0
# 9      727   9   9   9.0  0.0
# 10     727  10  10  10.0  0.0
# 11     727  11  11  11.0  0.0
# 12     728  12  12  12.0  0.0
# 13     729  13  13  13.0  0.0
# 14     729  14  14  14.0  0.0
# 15     729  15  15  15.0  0.0
# 16     730  16  16  16.0  0.0
# 17     730  17  17  17.0  0.0
# 18     728  18  18  18.0  0.0
# 19     728  19  19  19.0  0.0
# 20     728  20  20  20.0  0.0
# 21     728  21  21  21.0  0.0
# 22     728  22  22  22.0  0.0
# 23     728  23  23  23.0  0.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.groupby(by="mnth").agg({
    "instant": "nunique",
    "mnth": ["max", "min", "mean", "std"]
})
# Out:
#      instant mnth
#      nunique  max min  mean  std
# mnth
# 1         62    1   1   1.0  0.0
# 2         57    2   2   2.0  0.0
# 3         62    3   3   3.0  0.0
# 4         60    4   4   4.0  0.0
# 5         62    5   5   5.0  0.0
# 6         60    6   6   6.0  0.0
# 7         62    7   7   7.0  0.0
# 8         62    8   8   8.0  0.0
# 9         60    9   9   9.0  0.0
# 10        62   10  10  10.0  0.0
# 11        60   11  11  11.0  0.0
# 12        62   12  12  12.0  0.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.groupby(by="season").instant.nunique().sort_values(ascending=False)
# Out:
# season
# 3    4496
# 2    4409
# 1    4242
# 4    4232
# Name: instant, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.groupby(by="yr").instant.nunique().sort_values(ascending=False)
# Out:
# yr
# 1    8734
# 0    8645
# Name: instant, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.groupby(by="season").instant.nunique().sort_values(ascending=False)
# Out:
# season
# 3    188
# 2    184
# 1    181
# 4    178
# Name: instant, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
day_df.groupby(by="yr").instant.nunique().sort_values(ascending=False)
# Out:
# yr
# 1    366
# 0    365
# Name: instant, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
instant_in_day_df =  day_df.instant.tolist()
hour_df["status"] = hour_df["instant"].apply(lambda x: "Active" if x in instant_in_day_df else "Non Active")
hour_df.sample(5)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 1521      1522  2011-03-08       1   0     3  18        0        2
# 7816      7817  2011-11-27       4   0    11   7        0        0
# 2428      2429  2011-04-16       2   0     4   2        0        6
# 6382      6383  2011-09-28       4   0     9  12        0        3
# 13949    13950  2012-08-09       3   1     8  10        0        4
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 1521            1           1  0.34  0.3333  0.27     0.1940      21
# 7816            0           1  0.38  0.3939  0.87     0.2239      12
# 2428            0           2  0.36  0.3485  0.87     0.1343       5
# 6382            1           2  0.68  0.6364  0.79     0.0000      25
# 13949           1           1  0.80  0.7576  0.55     0.2239      72
#
#        registered  cnt      status
# 1521          214  235  Non Active
# 7816           11   23  Non Active
# 2428           19   24  Non Active
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour_df.groupby(by="status").instant.count()
# Out:
# status
# Active          731
# Non Active    16648
# Name: instant, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Visualization & Explanatory Analisis

# %% [markdown]
# Pertanyaan 1 :

# %%
colors = sns.color_palette("husl")

byhr_df = hour_df.groupby(by="hr").instant.nunique().reset_index()
byhr_df.rename(columns={
    "instant": "instant_count"
}, inplace=True)
 
plt.figure(figsize=(10, 5))
 
sns.barplot(
    y="instant_count", 
    x="hr",
    data=byhr_df.sort_values(by="instant_count", ascending=False),
    palette=colors
)
plt.title("Pemakaian Berdasarkan Jam", loc="center", fontsize=15)
plt.ylabel("instant")
plt.xlabel("hr")
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11536\2938791080.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\User\AppData\Local\Temp\ipykernel_11536\2938791080.py:10: UserWarning:
# The palette list has fewer values (6) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pertanyaan 2 :

# %%
bymnth_df = day_df.groupby(by="mnth").instant.nunique().reset_index()
bymnth_df.rename(columns={
    "instant": "instant_count"
}, inplace=True)
bymnth_df
plt.figure(figsize=(10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="mnth", 
    y="instant_count",
    data=bymnth_df.sort_values(by="instant_count", ascending=False),
    palette=colors_
)
plt.title("Pemakaian Berdasarkan Bulan", loc="center", fontsize=15)
plt.ylabel("instant")
plt.xlabel("mnth")
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11536\4102754765.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conclusion

# %% [markdown]
# Conclusion pertanyaan 1 : banyak user yang pemakaian sepeda 20 jam adalah 728 user, dan berdasarkan visualisasi data yang telah dilakukan terdapat pola tertentu yaitu banyak nya user yang pemakaian sepeda selama 7 sampai 23 jam

# %% [markdown]
# Conclusion pertanyaan 2 : terjadi penurunan pada bulan ke 2 yaitu sebanyak 57 user dan banyak user yang pemakaian sepeda 5 bulan adalah sebanyak 62 user

# %%
hour_df.to_csv("dashboard/main_data.csv", index=False)
